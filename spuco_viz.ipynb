# %%
baseline_log_f = "./spuco_results/baseline/baseline_log.json"
jtt_log_f = "./spuco_results/jtt/jtt_log.json"
spare_log_f = "./spuco_results/spare/spare_log.json"
baseline_best_eval_f = "./spuco_results/baseline/baseline_best_evalution.json"
jtt_best_eval_f = "./spuco_results/jtt/jtt_best_evalution.json"
spare_best_eval_f = "./spuco_results/spare/spare_best_evalution.json"
baseline_last_eval_f = "./spuco_results/baseline/baseline_last_evalution.json"
jtt_last_eval_f = "./spuco_results/jtt/jtt_last_evalution.json"
spare_last_eval_f = "./spuco_results/spare/spare_last_evalution.json"

# %%
import json

with open(baseline_log_f) as f1, \
     open(jtt_log_f) as f2,\
     open(spare_log_f) as f3:
    baseline_log = json.load(f1)["0"]["losses"]
    jtt_log = json.load(f2)["0"]["losses"]
    spare_log = json.load(f3)["0"]["losses"]

# %%
import matplotlib.pyplot as plt

iter = range(len(baseline_log)) # 1581
jtt_log = jtt_log[0:1581]

plt.plot(iter, baseline_log, color='r', label="baseline loss")
plt.plot(iter, jtt_log, color='g', label="jtt loss")
plt.plot(iter, spare_log, color='b', label="spare loss")
plt.xlabel('Iter')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
with open(baseline_best_eval_f) as f1, \
     open(baseline_last_eval_f) as f2, \
     open(jtt_best_eval_f) as f3, \
     open(jtt_last_eval_f) as f4, \
     open(spare_best_eval_f) as f5, \
     open(spare_last_eval_f) as f6:
    baseline_eval = json.load(f1)
    baseline_group_acc, baseline_worst_acc, baseline_avg_acc, baseline_best_acc, baseline_acc = baseline_eval["group_accuracy"], baseline_eval["worst_accuracy"], baseline_eval["avg_accuracy"], baseline_eval["best_accuracy"], baseline_eval["accuracy"]
    # baseline_last_eval = json.load(f2)
    jtt_eval = json.load(f3)
    jtt_group_acc, jtt_worst_acc, jtt_avg_acc, jtt_best_acc, jtt_acc = jtt_eval["group_accuracy"], jtt_eval["worst_accuracy"], jtt_eval["avg_accuracy"], jtt_eval["best_accuracy"], jtt_eval["accuracy"]
    # jtt_last_eval = json.load(f4)
    spare_eval = json.load(f5)
    spare_group_acc, spare_worst_acc, spare_avg_acc, spare_best_acc, spare_acc = spare_eval["group_accuracy"], spare_eval["worst_accuracy"], spare_eval["avg_accuracy"], spare_eval["best_accuracy"], spare_eval["accuracy"]
    # spare_last_eval = json.load(f6)

# %%
import numpy as np

ind = np.arange(len(baseline_group_acc))
width = 0.25
plt.figure(figsize=(18,6))
plt.bar(ind-width, list(baseline_group_acc.values()), width=width, color='r', label="baseline group acc")
plt.bar(ind, list(jtt_group_acc.values()), width=width, color='g', label="jtt group acc")
plt.bar(ind+width, list(spare_group_acc.values()), width=width, color='b', label="spare group acc")
plt.xticks(ind, list(baseline_group_acc.keys()), fontsize=6)
# plt.legend()
plt.show()


print(baseline_group_acc)
print(jtt_group_acc)
print(spare_group_acc)
# Out:
# {'MSA_unknown': 0.9080418348312378, 'MSA_MSA': 0.4285714626312256, 'MGH_TN': 0.8992248177528381, 'MGH_unknown': 0.7868852019309998, 'MGH_LY': 0.7093023061752319, 'MGH_MA': 0.9504643678665161, 'MGH_DZ': 0.9056603312492371, 'EGY_unknown': 0.7793103456497192, 'EGY_EG': 0.9197080135345459, 'EGY_SD': 0.65625, 'LEV_PL': 0.7209302186965942, 'LEV_JO': 0.7530863881111145, 'LEV_SY': 0.8735178112983704, 'LEV_LB': 0.9007633328437805, 'LEV_unknown': 0.6760563254356384, 'IRQ_IQ': 0.7371007204055786, 'IRQ_KW': 0.17391304671764374, 'GLF_unknown': 0.7087033987045288, 'GLF_AE': 0.625, 'GLF_BH': 0.8125, 'GLF_OM': 0.550000011920929, 'GLF_SA': 0.704119861125946, 'GLF_YE': 0.7152777910232544, 'GLF_QA': 0.8793103694915771}
# {'MSA_unknown': 0.8171654939651489, 'MSA_MSA': 0.3571428656578064, 'MGH_TN': 0.8720930218696594, 'MGH_unknown': 0.8032786250114441, 'MGH_LY': 0.5930232405662537, 'MGH_MA': 0.9442723989486694, 'MGH_DZ': 0.8427672386169434, 'EGY_unknown': 0.7724137902259827, 'EGY_EG': 0.9270073175430298, 'EGY_SD': 0.640625, 'LEV_PL': 0.7829457521438599, 'LEV_JO': 0.7654320597648621, 'LEV_SY': 0.8656126856803894, 'LEV_LB': 0.9465649127960205, 'LEV_unknown': 0.7288732528686523, 'IRQ_IQ': 0.7764127850532532, 'IRQ_KW': 0.3478260934352875, 'GLF_unknown': 0.7460035681724548, 'GLF_AE': 0.5625, 'GLF_BH': 0.75, 'GLF_OM': 0.6785714030265808, 'GLF_SA': 0.7528089880943298, 'GLF_YE': 0.7152777910232544, 'GLF_QA': 0.8706896305084229}
# {'MSA_unknown': 0.8672917485237122, 'MSA_MSA': 0.5714285969734192, 'MGH_TN': 0.8217054009437561, 'MGH_unknown': 0.7868852019309998, 'MGH_LY': 0.42635658383369446, 'MGH_MA': 0.9133126735687256, 'MGH_DZ': 0.7987421154975891, 'EGY_unknown': 0.7931034564971924, 'EGY_EG': 0.9197080135345459, 'EGY_SD': 0.5390625, 'LEV_PL': 0.7286821603775024, 'LEV_JO': 0.6748970746994019, 'LEV_SY': 0.8142293095588684, 'LEV_LB': 0.885496199131012, 'LEV_unknown': 0.6778168678283691, 'IRQ_IQ': 0.815724790096283, 'IRQ_KW': 0.1304347813129425, 'GLF_unknown': 0.7770870327949524, 'GLF_AE': 0.6875, 'GLF_BH': 0.8125, 'GLF_OM': 0.5928571224212646, 'GLF_SA': 0.7303370833396912, 'GLF_YE': 0.7222222089767456, 'GLF_QA': 0.9137930870056152}
